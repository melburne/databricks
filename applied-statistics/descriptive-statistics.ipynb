# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# # Descriptive Statistics
#
# **Objective**: *Use descriptive statistics to gather information about a data set.*
#
# In this lab, you will complete a series of exercises to calculate various summary statistics of the `dsfda.ht_daily_metrics` data set.

# %%
# %run "./Includes/Classroom-Setup"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Mounting course-specific datasets to <b>/mnt/training</b>...</br>Datasets are already mounted to <b>/mnt/training</b> from <b>s3a://databricks-corp-training/common</b>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: DataFrame[]</div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
# ...

# %% [markdown]
# ## Part 1: Measures of Central Tendency

# %% [markdown]
# #### Exercise 1: Mean
#
# Calculate the mean resting heartrate, as an integer, for each lifestyle.

# %%
# %sql
SELECT * FROM dsfda.ht_daily_metrics
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
-- TODO

SELECT CAST(AVG(resting_heartrate) AS int) AS mean_resting_heartrate, lifestyle
FROM dsfda.ht_daily_metrics
GROUP BY lifestyle
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mean_resting_heartrate</th><th>lifestyle</th></tr></thead><tbody><tr><td>53</td><td>Cardio Enthusiast</td></tr><tr><td>57</td><td>Athlete</td></tr><tr><td>73</td><td>Weight Trainer</td></tr><tr><td>79</td><td>Sedentary</td></tr></tbody></table></div>

# %% [markdown]
# #### Exercise 2: Median
#
# Calculate the median resting heartrate, as an integer, for the "Athlete" lifestyle.
#
# Note that this code block takes longer to run; this is because calculating the median requires shuffling across worker nodes.

# %%
# %sql
-- TODO

SELECT CAST(percentile(resting_heartrate, 0.5) AS int) as meadian_resting_heartrate
FROM dsfda.ht_daily_metrics
WHERE lifestyle='Athlete'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>meadian_resting_heartrate</th></tr></thead><tbody><tr><td>57</td></tr></tbody></table></div>

# %% [markdown]
# -sandbox
# #### Exercise 3: Mode
#
# Calculate the mode, as an integer, of the resting heartrate for each lifestyle.
#
# <img alt="Hint" title="Hint" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.3em" src="https://files.training.databricks.com/static/images/icon-light-bulb.svg"/>&nbsp;**Hint:** round the heartrate to `INT` first.

# %%
# %sql
-- TODO

SELECT COUNT(*) AS count, CAST(resting_heartrate AS int) AS resting_heartrate
FROM dsfda.ht_daily_metrics
GROUP BY resting_heartrate
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ## Part 2: Measures of Dispersion

# %% [markdown]
# -sandbox
# #### Exercise 4: Standard Deviation
#
# Calculate the standard deviation of the resting heartrate for each lifestyle.
#
# <img alt="Hint" title="Hint" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.3em" src="https://files.training.databricks.com/static/images/icon-light-bulb.svg"/>&nbsp;**Hint:** round the heartrate to `INT` first.

# %%
# %sql
-- TODO

SELECT CAST(STD(resting_heartrate) AS int) as std_resting_heartrate, lifestyle
FROM dsfda.ht_daily_metrics
GROUP BY lifestyle
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>std_resting_heartrate</th><th>lifestyle</th></tr></thead><tbody><tr><td>8</td><td>Cardio Enthusiast</td></tr><tr><td>9</td><td>Athlete</td></tr><tr><td>13</td><td>Weight Trainer</td></tr><tr><td>11</td><td>Sedentary</td></tr></tbody></table></div>

# %% [markdown]
# #### Exercise 5: Interquartile Range
#
# Calculate the interquartile range of resting heartrate, as an integer, for each lifestyle.

# %%
# %sql
-- TODO

SELECT CAST(percentile(resting_heartrate, 0.75) - percentile(resting_heartrate, 0.25) AS int) AS iqr_resting_heartrate
FROM dsfda.ht_daily_metrics
GROUP BY lifestyle
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>iqr_resting_heartrate</th></tr></thead><tbody><tr><td>10</td></tr><tr><td>12</td></tr><tr><td>19</td></tr><tr><td>16</td></tr></tbody></table></div>

# %% [markdown]
# -sandbox
# &copy; 2021 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
